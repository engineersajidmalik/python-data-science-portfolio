# %%
import numpy as np
import pandas as pd

# %%
# House prices ka array banayein aur stats nikalein
prices = np.array([100,120,110,130,5000])

print("Mean of House Prices is:", prices.mean())
print("Median of House Prices is:", np.median(prices))
print("Std of House Prices is:", prices.std())
# Out:
# Mean of House Prices is: 1092.0
# Median of House Prices is: 120.0
# Std of House Prices is: 1954.025588368791

# %%
data = np.array([10, 20, 30, 40, 5000, 60, 70])

mask = data > 1000
mask
# Out:
# array([False, False, False, False,  True, False, False])

# %%
array = pd.Series([10,20,30,40], index=['a','b','c','d'])
array
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
array.reset_index()
# Out:
#   index   0
# 0     a  10
# 1     b  20
# 2     c  30
# 3     d  40

# %%
a = pd.Series(np.arange(1,5), index=['a','b','c','d'])
a
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
filtering = a.where(a>2)
filtering
# Out:
# a    NaN
# b    NaN
# c    3.0
# d    4.0
# dtype: float64

# %% [markdown]
# Filtering Data

# %%
fil = np.array([10,20,30,40,50])
fil

fil2 = np.where(fil>20, "Good",np.where(fil<30, "Normal", "Bad"))
fil2
# Out:
# array(['Normal', 'Normal', 'Good', 'Good', 'Good'], dtype='<U6')

# %%
number = pd.DataFrame({"A":[1,2,3,4], "B":[5,6,7,8], "C":[9,10,11,12]})
number
# Out:
#    A  B   C
# 0  1  5   9
# 1  2  6  10
# 2  3  7  11
# 3  4  8  12

# %%
import pandas as pd

# Let's create a mock dataset of Smartphone Reviews
data = {
    'Brand': ['Apple', 'Samsung', 'Google', 'OnePlus', 'Xiaomi', 'Sony'],
    'Model': ['iPhone 15', 'Galaxy S24', 'Pixel 8', 'OnePlus 12', 'Redmi Note 13', 'Xperia 1 V'],
    'Release_Year': [2023, 2024, 2023, 2023, 2023, 2023],
    'Price': [799, 899, 699, 799, 299, 1399],
    'Battery_Life': [20, 24, 22, 28, 30, 18],
    'Camera_Rating': [9.5, 9.2, 9.4, 8.8, 8.0, 8.5],
    'OS': ['iOS', 'Android', 'Android', 'Android', 'Android', 'Android']
}

df_phones = pd.DataFrame(data)
df_phones.head()
# Out:
#      Brand          Model  Release_Year  Price  Battery_Life  Camera_Rating  \
# 0    Apple      iPhone 15          2023    799            20            9.5
# 1  Samsung     Galaxy S24          2024    899            24            9.2
# 2   Google        Pixel 8          2023    699            22            9.4
# 3  OnePlus     OnePlus 12          2023    799            28            8.8
# 4   Xiaomi  Redmi Note 13          2023    299            30            8.0
#
#         OS
# 0      iOS
# 1  Android
# 2  Android
# 3  Android
# 4  Android

# %%
three_rows = df_phones.head(3)
three_rows
# Out:
#      Brand       Model  Release_Year  Price  Battery_Life  Camera_Rating  \
# 0    Apple   iPhone 15          2023    799            20            9.5
# 1  Samsung  Galaxy S24          2024    899            24            9.2
# 2   Google     Pixel 8          2023    699            22            9.4
#
#         OS
# 0      iOS
# 1  Android
# 2  Android

# %%
df_specs = df_phones[['Model', 'Price']]
print(df_specs)
# Out:
#            Model  Price
# 0      iPhone 15    799
# 1     Galaxy S24    899
# 2        Pixel 8    699
# 3     OnePlus 12    799
# 4  Redmi Note 13    299
# 5     Xperia 1 V   1399

# %%
data = pd.read_csv("Datasets/people-100.csv")
data.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1       bethany14@example.com       214.112.6044x4913    1910-03-24
# 2       bthompson@example.com            277.609.7938    1992-07-02
# 3   kaitlinkaiser@example.com            584.094.6111    2017-08-03
# 4  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title
# 0     Games developer
# 1      Phytotherapist
# 2           Homeopath
# 3   Market researcher
# 4  Veterinary surgeon

# %%
# Apply indexing 
column_indexing = data.loc[::,'First Name':'Sex']
column_indexing.head()
# Out:
#   First Name Last Name     Sex
# 0     Shelby   Terrell    Male
# 1    Phillip   Summers  Female
# 2   Kristine    Travis    Male
# 3    Yesenia  Martinez    Male
# 4       Lori      Todd    Male

# %%
# Row and column indexing 
row_col_indexing = data.iloc[0:4,0:3]
row_col_indexing.head()
# Out:
#    Index          User Id First Name
# 0      1  88F7B33d2bcf9f5     Shelby
# 1      2  f90cD3E76f1A9b9    Phillip
# 2      3  DbeAb8CcdfeFC2c   Kristine
# 3      4  A31Bee3c201ef58    Yesenia

# %%
# Create a new column 
data['Salary'] = 0
data.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1       bethany14@example.com       214.112.6044x4913    1910-03-24
# 2       bthompson@example.com            277.609.7938    1992-07-02
# 3   kaitlinkaiser@example.com            584.094.6111    2017-08-03
# 4  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title  Salary
# 0     Games developer       0
# 1      Phytotherapist       0
# 2           Homeopath       0
# 3   Market researcher       0
# 4  Veterinary surgeon       0

# %%
pd.read_csv('Datasets/people-100.csv')
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1        bethany14@example.com       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %%
data['Salary'] = 0
print(data.head())
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1       bethany14@example.com       214.112.6044x4913    1910-03-24
# 2       bthompson@example.com            277.609.7938    1992-07-02
# 3   kaitlinkaiser@example.com            584.094.6111    2017-08-03
# 4  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title  Salary
# 0     Games developer       0
# 1      Phytotherapist       0
# 2           Homeopath       0
# 3   Market researcher       0
# 4  Veterinary surgeon       0

# %%
data['Salary'] = np.where(data['Sex'] == 'Male', 2000, 1000)
data.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1       bethany14@example.com       214.112.6044x4913    1910-03-24
# 2       bthompson@example.com            277.609.7938    1992-07-02
# 3   kaitlinkaiser@example.com            584.094.6111    2017-08-03
# 4  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title  Salary
# 0     Games developer    2000
# 1      Phytotherapist    1000
# 2           Homeopath    2000
# 3   Market researcher    2000
# 4  Veterinary surgeon    2000

# %%
data['Grade'] = np.where(data['Salary'] > 1500, 'A', 'B')
data.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1       bethany14@example.com       214.112.6044x4913    1910-03-24
# 2       bthompson@example.com            277.609.7938    1992-07-02
# 3   kaitlinkaiser@example.com            584.094.6111    2017-08-03
# 4  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title  Salary Grade
# 0     Games developer    2000     A
# 1      Phytotherapist    1000     B
# 2           Homeopath    2000     A
# 3   Market researcher    2000     A
# 4  Veterinary surgeon    2000     A

# %%
# adding a row
new_row = pd.DataFrame({'index': [1],'User Id': ['123gnkons'], 'First Name': ['Sajid'], 'Last Name': ['Malik'], 'Sex': ['Male'], 'Email': ['jdoe@example.com'], 'Phone': ['123-456-7890'], 'Date of birth': ['2002-01-01'], 'Job Title': ['Software Engineer']})
# Now adding a row need to concat it with the esisiting data
data = pd.concat([data, new_row], ignore_index=True)
data.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0    1.0  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1    2.0  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2    3.0  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 3    4.0  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4    5.0  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1       bethany14@example.com       214.112.6044x4913    1910-03-24
# 2       bthompson@example.com            277.609.7938    1992-07-02
# 3   kaitlinkaiser@example.com            584.094.6111    2017-08-03
# 4  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title  Salary Grade  index
# 0     Games developer  2000.0     A    NaN
# 1      Phytotherapist  1000.0     B    NaN
# 2           Homeopath  2000.0     A    NaN
# 3   Market researcher  2000.0     A    NaN
# ...

# %%
data.loc['Email':'elijah57@example.net']
# Out:
# Empty DataFrame
# Columns: [Index, User Id, First Name, Last Name, Sex, Email, Phone, Date of birth, Job Title, Salary, Grade, index]
# Index: []

# %%
pd.read_csv("Datasets/people-100.csv")
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1        bethany14@example.com       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %% [markdown]
# MultiIndex

# %%
pd.read_csv("Datasets/people-100.csv")
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1        bethany14@example.com       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %%
# Now we apply set_index() method 
multi_index = data.set_index(['First Name', 'Last Name'])
multi_index.head()
# Out:
#                       Index          User Id     Sex  \
# First Name Last Name
# Shelby     Terrell      1.0  88F7B33d2bcf9f5    Male
# Phillip    Summers      2.0  f90cD3E76f1A9b9  Female
# Kristine   Travis       3.0  DbeAb8CcdfeFC2c    Male
# Yesenia    Martinez     4.0  A31Bee3c201ef58    Male
# Lori       Todd         5.0  1bA7A3dc874da3c    Male
#
#                                            Email                   Phone  \
# First Name Last Name
# Shelby     Terrell          elijah57@example.net  001-084-906-7849x73518
# Phillip    Summers         bethany14@example.com       214.112.6044x4913
# Kristine   Travis          bthompson@example.com            277.609.7938
# Yesenia    Martinez    kaitlinkaiser@example.com            584.094.6111
# Lori       Todd       buchananmanuel@example.net       689-207-3558x7233
#
#                      Date of birth           Job Title  Salary Grade  index
# First Name Last Name
# ...

# %%
multi_index.loc[('Phillip', 'Summers')]
# Out:
# Index                              2.0
# User Id                f90cD3E76f1A9b9
# Sex                             Female
# Email            bethany14@example.com
# Phone                214.112.6044x4913
# Date of birth               1910-03-24
# Job Title               Phytotherapist
# Salary                          1000.0
# Grade                                B
# index                              NaN
# Name: (Phillip, Summers), dtype: object

# %%
import pandas as pd

store_data = {
    'Region':   ['North', 'North', 'North', 'South', 'South', 'South', 'East', 'East'],
    'Category': ['Electronics', 'Electronics', 'Clothing', 'Electronics', 'Clothing', 'Clothing', 'Electronics', 'Clothing'],
    'Product':  ['Laptop', 'Phone', 'T-Shirt', 'Laptop', 'T-Shirt', 'Jeans', 'Phone', 'Jeans'],
    'Sales':    [1200, 800, 150, 1100, 180, 220, 750, 200],
    'Profit':   [240, 160, 45, 220, 54, 66, 150, 60],
    'Qty':      [12, 20, 30, 11, 36, 22, 15, 25]
}

df = pd.DataFrame(store_data)
print(df)
# Out:
#   Region     Category  Product  Sales  Profit  Qty
# 0  North  Electronics   Laptop   1200     240   12
# 1  North  Electronics    Phone    800     160   20
# 2  North     Clothing  T-Shirt    150      45   30
# 3  South  Electronics   Laptop   1100     220   11
# 4  South     Clothing  T-Shirt    180      54   36
# 5  South     Clothing    Jeans    220      66   22
# 6   East  Electronics    Phone    750     150   15
# 7   East     Clothing    Jeans    200      60   25

# %%
sale = df.set_index(['Region', 'Category'])
sale
# Out:
#                     Product  Sales  Profit  Qty
# Region Category
# North  Electronics   Laptop   1200     240   12
#        Electronics    Phone    800     160   20
#        Clothing     T-Shirt    150      45   30
# South  Electronics   Laptop   1100     220   11
#        Clothing     T-Shirt    180      54   36
#        Clothing       Jeans    220      66   22
# East   Electronics    Phone    750     150   15
#        Clothing       Jeans    200      60   25

# %%
sale.loc[('North', 'Clothing')]
# Out:
# C:\Users\LAPTOP GENERATION\AppData\Local\Temp\ipykernel_16660\544955997.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   sale.loc[('North', 'Clothing')]
#                  Product  Sales  Profit  Qty
# Region Category
# North  Clothing  T-Shirt    150      45   30

# %%
sales1 = df.set_index(['Region','Category','Product','Sales','Profit','Qty'])
sales1
# Out:
# Empty DataFrame
# Columns: []
# Index: [(North, Electronics, Laptop, 1200, 240, 12), (North, Electronics, Phone, 800, 160, 20), (North, Clothing, T-Shirt, 150, 45, 30), (South, Electronics, Laptop, 1100, 220, 11), (South, Clothing, T-Shirt, 180, 54, 36), (South, Clothing, Jeans, 220, 66, 22), (East, Electronics, Phone, 750, 150, 15), (East, Clothing, Jeans, 200, 60, 25)]

# %%
sales1.loc[('North', 'Electronics', 'Laptop', 1200, 240, 12)]
# Out:
# Series([], Name: (North, Electronics, Laptop, 1200, 240, 12), dtype: float64)
