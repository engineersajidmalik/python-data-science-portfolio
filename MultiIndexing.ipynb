# %%
import numpy as np
import pandas as pd

# %%
df_sales = pd.read_csv('Datasets/sales_data_sample.csv', sep=',', encoding='latin1')
df_sales.sort_index()
df_sales.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df_sales.set_index(['PRICEEACH','SALES'], inplace=True)
df_sales.head()
# Out:
#                    ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER  \
# PRICEEACH SALES
# 95.70     2871.00        10107               30                2
# 81.35     2765.90        10121               34                5
# 94.74     3884.34        10134               41                2
# 83.26     3746.70        10145               45                6
# 100.00    5205.27        10159               49               14
#
#                          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  \
# PRICEEACH SALES
# 95.70     2871.00   2/24/2003 0:00  Shipped       1         2     2003
# 81.35     2765.90    5/7/2003 0:00  Shipped       2         5     2003
# 94.74     3884.34    7/1/2003 0:00  Shipped       3         7     2003
# 83.26     3746.70   8/25/2003 0:00  Shipped       3         8     2003
# 100.00    5205.27  10/10/2003 0:00  Shipped       4        10     2003
#
#                    PRODUCTLINE  MSRP  ...                   ADDRESSLINE1  \
# ...

# %%
df_sales.index
# Out:
# MultiIndex([( 95.7,  2871.0),
#             (81.35,  2765.9),
#             (94.74, 3884.34),
#             (83.26,  3746.7),
#             (100.0, 5205.27),
#             (96.66, 3479.76),
#             (86.13, 2497.77),
#             (100.0, 5512.32),
#             (98.57, 2168.54),
#             (100.0, 4708.44),
#             ...
#             (60.06, 1921.92),
#             (59.51, 2082.85),
#             (55.69,  2227.6),
#             (86.74, 3209.38),
#             (97.16, 4080.72),
#             (100.0,  2244.4),
#             (100.0, 3978.51),
#             (100.0, 5417.57),
#             (62.24, 2116.16),
#             (65.52, 3079.44)],
#            names=['PRICEEACH', 'SALES'], length=2823)

# %%
df_sales.index.levels
# Out:
# FrozenList([[26.88, 27.22, 28.29, 28.88, 29.21, 29.54, 29.7, 29.87, 30.06, 30.2, 30.59, 30.96, 31.12, 31.2, 31.47, 31.53, 31.82, 31.86, 32.1, 32.47, 32.59, 32.88, 32.99, 33.19, 33.23, 33.24, 34.19, 34.36, 34.47, 34.88, 34.91, 35.18, 35.29, 35.35, 35.4, 35.49, 35.51, 35.71, 35.8, 35.87, 36.07, 36.11, 36.21, 36.29, 36.42, 36.61, 36.63, 36.66, 36.74, 36.84, 36.93, 37.0, 37.13, 37.17, 37.18, 37.34, 37.48, 37.5, 37.63, 37.84, 37.97, 38.08, 38.17, 38.19, 38.22, 38.4, 38.5, 38.52, 38.89, 38.9, 38.98, 39.42, 39.43, 39.6, 39.65, 39.8, 39.83, 40.15, 40.21, 40.22, 40.23, 40.25, 40.31, 40.4, 40.62, 40.66, 41.02, 41.03, 41.22, 41.54, 41.71, 41.72, 41.85, 41.91, 42.24, 42.26, 42.43, 42.64, 42.67, 42.76, ...], [482.13, 541.14, 553.95, 577.6, 640.05, 651.8, 652.35, 683.8, 694.6, 703.6, 710.2, 717.4, 721.44, 728.4, 733.11, 759.46, 777.0, 785.64, 813.2, 820.4, 828.36, 834.67, 845.25, 846.51, 856.52, 859.14, 865.49, 875.91, 881.4, 891.03, 891.2, 902.66, 905.28, 913.92, 917.7, 925.3, 930.9, 935.18, 948.
# ...

# %%
df_sales.index.get_level_values(0)
# Out:
# Index([ 95.7, 81.35, 94.74, 83.26, 100.0, 96.66, 86.13, 100.0, 98.57, 100.0,
#        ...
#        60.06, 59.51, 55.69, 86.74, 97.16, 100.0, 100.0, 100.0, 62.24, 65.52],
#       dtype='float64', name='PRICEEACH', length=2823)

# %%
df_sales.index.get_level_values(1)
# Out:
# Index([ 2871.0,  2765.9, 3884.34,  3746.7, 5205.27, 3479.76, 2497.77, 5512.32,
#        2168.54, 4708.44,
#        ...
#        1921.92, 2082.85,  2227.6, 3209.38, 4080.72,  2244.4, 3978.51, 5417.57,
#        2116.16, 3079.44],
#       dtype='float64', name='SALES', length=2823)

# %%
df_sales.index.get_level_values('PRICEEACH')
# Out:
# Index([ 95.7, 81.35, 94.74, 83.26, 100.0, 96.66, 86.13, 100.0, 98.57, 100.0,
#        ...
#        60.06, 59.51, 55.69, 86.74, 97.16, 100.0, 100.0, 100.0, 62.24, 65.52],
#       dtype='float64', name='PRICEEACH', length=2823)

# %%
df_sales.index.get_level_values('SALES')
# Out:
# Index([ 2871.0,  2765.9, 3884.34,  3746.7, 5205.27, 3479.76, 2497.77, 5512.32,
#        2168.54, 4708.44,
#        ...
#        1921.92, 2082.85,  2227.6, 3209.38, 4080.72,  2244.4, 3978.51, 5417.57,
#        2116.16, 3079.44],
#       dtype='float64', name='SALES', length=2823)

# %%
multi_index = pd.read_csv('Datasets/sales_data_sample.csv', sep=',', encoding='latin1')
multi_index.sort_index(inplace=True)
multi_index.head()

multi_index.set_index(['PRICEEACH','SALES'], inplace=True)
multi_index.head()
# Out:
#                    ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER  \
# PRICEEACH SALES
# 95.70     2871.00        10107               30                2
# 81.35     2765.90        10121               34                5
# 94.74     3884.34        10134               41                2
# 83.26     3746.70        10145               45                6
# 100.00    5205.27        10159               49               14
#
#                          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  \
# PRICEEACH SALES
# 95.70     2871.00   2/24/2003 0:00  Shipped       1         2     2003
# 81.35     2765.90    5/7/2003 0:00  Shipped       2         5     2003
# 94.74     3884.34    7/1/2003 0:00  Shipped       3         7     2003
# 83.26     3746.70   8/25/2003 0:00  Shipped       3         8     2003
# 100.00    5205.27  10/10/2003 0:00  Shipped       4        10     2003
#
#                    PRODUCTLINE  MSRP  ...                   ADDRESSLINE1  \
# ...

# %%
idx1 = pd.IndexSlice
multi_index.loc[idx1[95.70,:],:]
# Out:
#                   ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER  \
# PRICEEACH SALES
# 95.7      2871.0        10107               30                2
#
#                        ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  \
# PRICEEACH SALES
# 95.7      2871.0  2/24/2003 0:00  Shipped       1         2     2003
#
#                   PRODUCTLINE  MSRP  ...             ADDRESSLINE1  \
# PRICEEACH SALES                      ...
# 95.7      2871.0  Motorcycles    95  ...  897 Long Airport Avenue
#
#                  ADDRESSLINE2 CITY STATE POSTALCODE COUNTRY TERRITORY  \
# PRICEEACH SALES
# 95.7      2871.0          NaN  NYC    NY      10022     USA       NaN
#
#                  CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# PRICEEACH SALES
# 95.7      2871.0              Yu             Kwai    Small
#
# [1 rows x 23 columns]

# %%
sort = multi_index.sort_index()
sort.loc[idx1[80:100, :], :]
# Out:
#                     ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER  \
# PRICEEACH SALES
# 80.00     3440.00         10327               43                2
# 80.10     3204.00         10267               40                5
# 80.34     2169.18         10159               27               11
#           2972.58         10224               37                4
# 80.41     2171.07         10310               27               13
# ...                         ...              ...              ...
# 100.00    11886.60        10403               66                9
#           11887.80        10412               60                9
#           12001.00        10424               50                6
#           12536.50        10322               50                6
#           14082.80        10407               76                2
#
#                           ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  \
# PRICEEACH SALES
# ...

# %%
sort2 = multi_index.sort_index()
sort2.loc[idx1[80:100, 2000:3000],'ORDERNUMBER':'ORDERLINENUMBER']
sort2.head()
# Out:
#                    ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER  \
# PRICEEACH SALES
# 26.88     1209.60        10420               45                1
# 27.22     1007.14        10162               37                5
# 28.29     905.28         10195               32                7
# 28.88     577.60         10280               20               12
# 29.21     759.46         10193               26               10
#
#                          ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  \
# PRICEEACH SALES
# 26.88     1209.60   5/29/2005 0:00  In Process       2         5     2005
# 27.22     1007.14  10/18/2003 0:00     Shipped       4        10     2003
# 28.29     905.28   11/25/2003 0:00     Shipped       4        11     2003
# 28.88     577.60    8/17/2004 0:00     Shipped       3         8     2004
# 29.21     759.46   11/21/2003 0:00     Shipped       4        11     2003
#
#                     PRODUCTLINE  MSRP  ...  \
# PRICEEACH SALES                        ...
# ...

# %%
df_multi_index = pd.read_csv("Datasets/sales_data_sample.csv", sep=",", encoding="latin1")
df_multi_index.sort_index(inplace=True)
df_multi_index.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df_multi_index.set_index(['ORDERNUMBER','QUANTITYORDERED','PRICEEACH'], inplace=True)
df_multi_index.head()
# Out:
#                                        ORDERLINENUMBER    SALES  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH
# 10107       30              95.70                    2  2871.00
# 10121       34              81.35                    5  2765.90
# 10134       41              94.74                    2  3884.34
# 10145       45              83.26                    6  3746.70
# 10159       49              100.00                  14  5205.27
#
#                                              ORDERDATE   STATUS  QTR_ID  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH
# 10107       30              95.70       2/24/2003 0:00  Shipped       1
# 10121       34              81.35        5/7/2003 0:00  Shipped       2
# 10134       41              94.74        7/1/2003 0:00  Shipped       3
# 10145       45              83.26       8/25/2003 0:00  Shipped       3
# 10159       49              100.00     10/10/2003 0:00  Shipped       4
#
# ...

# %%
slice_idx = pd.IndexSlice
df_multi_index.sort_index(inplace=True)
df_multi_index.loc[slice_idx[::,::,80.00:90.00,:],:]
df_multi_index.head()
# Out:
#                                        ORDERLINENUMBER    SALES  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH
# 10100       22              86.51                    4  1903.22
#             30              100.00                   3  5151.00
#             49              34.47                    1  1689.03
#             50              67.80                    2  3390.00
# 10101       25              100.00                   4  3782.00
#
#                                            ORDERDATE   STATUS  QTR_ID  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH
# 10100       22              86.51      1/6/2003 0:00  Shipped       1
#             30              100.00     1/6/2003 0:00  Shipped       1
#             49              34.47      1/6/2003 0:00  Shipped       1
#             50              67.80      1/6/2003 0:00  Shipped       1
# 10101       25              100.00     1/9/2003 0:00  Shipped       1
#
#                                        MONTH_ID  YEAR_ID   PRODUCTLINE  MSRP  \
# ...

# %%
slice_idx2 = pd.IndexSlice
df_multi_index.sort_index(inplace=True)
df_multi_index.loc[slice_idx2[::,::,80.00:90.00],'SALES':'YEAR_ID']
df_multi_index.head()
# Out:
#                                        ORDERLINENUMBER    SALES  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH
# 10100       22              86.51                    4  1903.22
#             30              100.00                   3  5151.00
#             49              34.47                    1  1689.03
#             50              67.80                    2  3390.00
# 10101       25              100.00                   4  3782.00
#
#                                            ORDERDATE   STATUS  QTR_ID  \
# ORDERNUMBER QUANTITYORDERED PRICEEACH
# 10100       22              86.51      1/6/2003 0:00  Shipped       1
#             30              100.00     1/6/2003 0:00  Shipped       1
#             49              34.47      1/6/2003 0:00  Shipped       1
#             50              67.80      1/6/2003 0:00  Shipped       1
# 10101       25              100.00     1/9/2003 0:00  Shipped       1
#
#                                        MONTH_ID  YEAR_ID   PRODUCTLINE  MSRP  \
# ...

# %%
tuple_slicing = pd.read_csv("Datasets/sales_data_sample.csv", sep=",", encoding="latin1")
tuple_slicing.sort_index(inplace=True)
tuple_slicing.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
tuple_slicing.set_index(['ORDERNUMBER','QUANTITYORDERED','ORDERLINENUMBER'], inplace=True)
tuple_slicing.head()
# Out:
#                                              PRICEEACH    SALES  \
# ORDERNUMBER QUANTITYORDERED ORDERLINENUMBER
# 10107       30              2                    95.70  2871.00
# 10121       34              5                    81.35  2765.90
# 10134       41              2                    94.74  3884.34
# 10145       45              6                    83.26  3746.70
# 10159       49              14                  100.00  5205.27
#
#                                                    ORDERDATE   STATUS  QTR_ID  \
# ORDERNUMBER QUANTITYORDERED ORDERLINENUMBER
# 10107       30              2                 2/24/2003 0:00  Shipped       1
# 10121       34              5                  5/7/2003 0:00  Shipped       2
# 10134       41              2                  7/1/2003 0:00  Shipped       3
# 10145       45              6                 8/25/2003 0:00  Shipped       3
# 10159       49              14               10/10/2003 0:00  Shipped       4
#
# ...

# %%
t = pd.IndexSlice
tuple_slicing.sort_index(inplace=True)
tuple_slicing.loc[t[10107:10159:,20:40:,::],:]
tuple_slicing.head()
# Out:
#                                              PRICEEACH    SALES  \
# ORDERNUMBER QUANTITYORDERED ORDERLINENUMBER
# 10100       22              4                    86.51  1903.22
#             30              3                   100.00  5151.00
#             49              1                    34.47  1689.03
#             50              2                    67.80  3390.00
# 10101       25              4                   100.00  3782.00
#
#                                                  ORDERDATE   STATUS  QTR_ID  \
# ORDERNUMBER QUANTITYORDERED ORDERLINENUMBER
# 10100       22              4                1/6/2003 0:00  Shipped       1
#             30              3                1/6/2003 0:00  Shipped       1
#             49              1                1/6/2003 0:00  Shipped       1
#             50              2                1/6/2003 0:00  Shipped       1
# 10101       25              4                1/9/2003 0:00  Shipped       1
#
# ...

# %%
print(tuple_slicing.loc[[10107]].head())
# Out:
#                                              PRICEEACH    SALES  \
# ORDERNUMBER QUANTITYORDERED ORDERLINENUMBER
# 10107       20              8                    92.90  1858.00
#             21              1                   100.00  3036.60
#             25              3                   100.00  2845.75
#             27              4                   100.00  6065.55
#             29              6                    70.87  2055.23
#
#                                                   ORDERDATE   STATUS  QTR_ID  \
# ORDERNUMBER QUANTITYORDERED ORDERLINENUMBER
# 10107       20              8                2/24/2003 0:00  Shipped       1
#             21              1                2/24/2003 0:00  Shipped       1
#             25              3                2/24/2003 0:00  Shipped       1
#             27              4                2/24/2003 0:00  Shipped       1
#             29              6                2/24/2003 0:00  Shipped       1
#
# ...
