# %%
import pandas as pd
import numpy as np

# %%
s1 = pd.Series([1,2,3,4,5])
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s2 = pd.Series(np.array([1,2,3,4,5]))
s2
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# Panadas k seies ma hm Positional Index k sath sath label index bi dey sakty hy . Ye display tb sirf label ko kry ga but positional bhi sath ho ga always

# %%
s3 = pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])
s3
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s4 = pd.Series(10, index=['a','b','c','d','e'])
s4
# Out:
# a    10
# b    10
# c    10
# d    10
# e    10
# dtype: int64

# %%
map = {'Ali':76, 'Omer':88, 'Veli':99, 'Ayse':66, 'Fatma':77}
s5 = pd.Series(map, dtype='int8')
print(s5)
print(s5.ndim)
# Out:
# Ali      76
# Omer     88
# Veli     99
# Ayse     66
# Fatma    77
# dtype: int8
# 1

# %%
s9 = pd.Series(10,index=['a','b','c','d','e'])
s9
# Out:
# a    10
# b    10
# c    10
# d    10
# e    10
# dtype: int64

# %%
map = pd.Series({"Ali":80, "Omer":90, "Veli":95, "Ayse":85, "Fatma":75})
map
# Out:
# Ali      80
# Omer     90
# Veli     95
# Ayse     85
# Fatma    75
# dtype: int64

# %%
map.loc["Ali"]
map.loc["Fatma"]
map.loc["Veli"]

map.iloc[0]
map.iloc[3]
# Out:
# np.int64(85)

# %%
s10 = pd.Series([1,None,2,None,3])
s10
# Out:
# <bound method Series.count of 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    3.0
# dtype: float64>

# %%
print(s10.size)
# Out:
# 5

# %%
map > 80
# Out:
# Ali      False
# Omer      True
# Veli      True
# Ayse      True
# Fatma    False
# dtype: bool

# %%
# In this case it return only filtered values
map[map > 80]
# Out:
# Omer    90
# Veli    95
# Ayse    85
# dtype: int64

# %%
map.iloc[[1,2]]
# Out:
# Omer    90
# Veli    95
# dtype: int64

# %%
map.reset_index()
# Out:
#    index   0
# 0    Ali  80
# 1   Omer  90
# 2   Veli  95
# 3   Ayse  85
# 4  Fatma  75
